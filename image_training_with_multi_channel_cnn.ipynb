# %%
# !pip install pyts

# %%
import os
import pandas as pd
import numpy as np
import multiprocessing
import tensorflow as tf

class color:
   PURPLE = '\033[95m'
   CYAN = '\033[96m'
   DARKCYAN = '\033[36m'
   BLUE = '\033[94m'
   GREEN = '\033[92m'
   YELLOW = '\033[93m'
   RED = '\033[91m'
   BOLD = '\033[1m'
   UNDERLINE = '\033[4m'
   END = '\033[0m'
    

RND_SEED = 0
GPU_ID = 0
USE_GPU = True

if tf.config.list_physical_devices('GPU') and USE_GPU:
    gpus = tf.config.experimental.list_physical_devices('GPU')
    gpu_name = gpus[0].name  # You may specify an index if using multiple GPUs
    print(f"Using GPU - {gpu_name}")
    device = '/GPU:0'
else:
    device = '/CPU:0'

# To use the device, you can use a context manager in TensorFlow:
with tf.device(device):
    # Your code that uses the specified device
    pass

print(f"Using device {device}")

N_CPU_CORES = multiprocessing.cpu_count()

BASE_FOLDER = os.path.join(
    "..", "input", "tlvmc-parkinsons-freezing-gait-prediction"
)

print(f"Number of CPU cores available: {N_CPU_CORES}")

pd.set_option('display.max_columns', 30)
pd.set_option('display.max_rows', 200)

from sklearn.metrics import f1_score
import os
import numpy as np
from tensorflow.keras.utils import Sequence, to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img
# Out:
# Using GPU - /physical_device:GPU:0
# Using device /GPU:0
# Number of CPU cores available: 12

# %%
class CustomMultiInputDataGenerator(Sequence):
    def __init__(self, directories, batch_size=32, image_size=(64, 64), shuffle=True, augment=False, num_classes=2, **kwargs):
        """
        directories: List of directories, one for each input branch.
        """
        super().__init__(**kwargs)
        self.directories = directories
        self.batch_size = batch_size
        self.image_size = image_size
        self.shuffle = shuffle
        self.augment = augment
        self.num_classes = num_classes
        self.image_paths = self._load_image_paths()
        self.samples = len(self.image_paths[0])  # Assume all branches have the same number of images
        
        # Initialize the ImageDataGenerator for augmentation
        self.datagen = ImageDataGenerator(
            rescale=1/255.0,
            width_shift_range=0.1 if self.augment else 0,
            height_shift_range=0.1 if self.augment else 0
        )
        
        self.on_epoch_end()

    def _load_image_paths(self):
        # Load image paths for each branch directory
        image_paths = []
        for directory in self.directories:
            branch_image_paths = [os.path.join(directory, fname) for fname in os.listdir(directory) if fname.endswith('.jpg')]
            image_paths.append(branch_image_paths)
        return image_paths

    def _get_class_from_filename(self, filename):
        # Extract label from filename assuming a naming convention
        class_label = int(filename.split('_')[-1].split('.')[0])
        return class_label

    def __len__(self):
        return int(np.ceil(self.samples / self.batch_size))

    def __getitem__(self, index):
        # Load a batch of images for each branch
        batch_image_paths = [paths[index * self.batch_size:(index + 1) * self.batch_size] for paths in self.image_paths]
        
        # Load and preprocess images for each branch
        images_per_branch = []
        for branch_paths in batch_image_paths:
            images = np.array([img_to_array(load_img(path, target_size=self.image_size)) for path in branch_paths])
            if self.augment:
                images = np.array([self.datagen.random_transform(image) for image in images])
            else:
                images = self.datagen.standardize(images)
            images_per_branch.append(images)

        # Load labels (assuming the same labels for each branch)
        labels = np.array([self._get_class_from_filename(os.path.basename(path)) for path in batch_image_paths[0]])
        labels = to_categorical(labels, num_classes=self.num_classes)
        
        return images_per_branch, labels

    def on_epoch_end(self):
        if self.shuffle:
            for branch_paths in self.image_paths:
                np.random.shuffle(branch_paths)

# %%
from models.cnn_models import create_multi_input_cnn
img_shape = (64, 64)

# %%
train_directories = ["data/mean_subtract/gaf_images/AccAP/train", "data/mean_subtract/gaf_images/AccML/train", "data/mean_subtract/gaf_images/AccV/train"]

val_directories = ["data/mean_subtract/gaf_images/AccAP/valid", "data/mean_subtract/gaf_images/AccML/valid", "data/mean_subtract/gaf_images/AccV/valid"]

train_generator = CustomMultiInputDataGenerator(
    directories=train_directories,
    batch_size=32,
    image_size=img_shape,
    augment=False,
    num_classes=2
)

val_generator = CustomMultiInputDataGenerator(
    directories=val_directories,
    batch_size=32,
    image_size=img_shape,
    augment=False,
    num_classes=2
)

model = create_multi_input_cnn()

history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=60
)

# %% [markdown]
# # Save Model

# %%
import pickle

# %%
with open('model_history.pkl', 'wb') as f:
    pickle.dump(history.history, f)

# %%
with open('model_history.pkl', 'rb') as f:
    loaded_history = pickle.load(f)

# %%
model.save('multi_input_cnn_model_0_9067_f1score_60_epoch.h5')

# %% [markdown]
# # Get Model

# %%
from tensorflow.keras.models import load_model
from tensorflow.keras import backend as K

def f1_metric(y_true, y_pred):
    # Convert predictions from softmax to class predictions
    y_true = tf.argmax(y_true, axis=-1)
    y_pred = tf.argmax(y_pred, axis=-1)

    # Cast to float32 for compatibility
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)

    # Calculate metrics
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))

    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())

    f1_val = 2 * (precision * recall) / (precision + recall + K.epsilon())
    return f1_val

model = load_model('multi_input_cnn_model_0_9067_f1score_60_epoch.h5', custom_objects={'f1_metric': f1_metric})

# %% [markdown]
# # Plot Performance

# %%
from matplotlib import pyplot as plt

# %%
fig = plt.figure()
plt.plot(history.history['loss'], color='teal', label='loss')
plt.plot(history.history['val_loss'], color='orange', label='val_loss')
fig.suptitle('Loss', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %%
fig = plt.figure()
plt.plot(history.history['accuracy'], color='teal', label='accuracy')
plt.plot(history.history['val_accuracy'], color='orange', label='val_accuracy')
fig.suptitle('Accuracy', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %% [markdown]
# # FOG Detection

# %%
def evaluate_model(model, generator):
    y_true = []
    y_pred = []
    
    for i in range(len(generator)):
        images, batch_y_true = generator[i]
        
        # Get predictions from model
        batch_predictions = model.predict(images, verbose=0)
        
        # Convert softmax output to binary class predictions
        batch_y_pred = np.argmax(batch_predictions, axis=1)
        
        # Flatten ground truth if it's one-hot encoded
        batch_y_true = np.argmax(batch_y_true, axis=1)
        
        y_true.extend(batch_y_true.flatten())
        y_pred.extend(batch_y_pred.flatten())
    
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    
    metrics = {
        'f1_micro': f1_score(y_true, y_pred, average='micro'),
        'f1_macro': f1_score(y_true, y_pred, average='macro'),
        'f1_weighted': f1_score(y_true, y_pred, average='weighted'),
        'f1_per_class': f1_score(y_true, y_pred, average=None)
    }
    
    return metrics

test_directories = ["data/mean_subtract/gaf_images/AccAP/test", "data/mean_subtract/gaf_images/AccML/test", "data/mean_subtract/gaf_images/AccV/test"]

test_generator = CustomMultiInputDataGenerator(
    directories=test_directories,
    batch_size=32,
    image_size=img_shape,
    augment=False,
    num_classes=2
)

results = evaluate_model(model, test_generator)

print("\nModel Evaluation Results:")
print(f"Micro F1 Score: {results['f1_micro']:.4f}")
print(f"Macro F1 Score: {results['f1_macro']:.4f}")
print(f"Weighted F1 Score: {results['f1_weighted']:.4f}")
print("\nF1 Score per class:")
for i, score in enumerate(results['f1_per_class']):
    print(f"Class {i}: {score:.4f}")
# Out:
# Model Evaluation Results:
# Micro F1 Score: 0.8759
# Macro F1 Score: 0.8586
# Weighted F1 Score: 0.8756
#
# F1 Score per class:
# Class 0: 0.8091
# Class 1: 0.9081

# %%
from sklearn.metrics import f1_score, confusion_matrix
import numpy as np

def evaluate_model(model, generator):
    y_true = []
    y_pred = []
    
    # Loop over the generator to collect all predictions and true labels
    for i in range(len(generator)):
        images, batch_y_true = generator[i]
        
        # Get predictions from the model
        batch_predictions = model.predict(images, verbose=0)
        
        # Convert softmax output to binary class predictions
        batch_y_pred = np.argmax(batch_predictions, axis=1)
        
        # Convert ground truth if it's one-hot encoded
        batch_y_true = np.argmax(batch_y_true, axis=1)
        
        y_true.extend(batch_y_true.flatten())
        y_pred.extend(batch_y_pred.flatten())
    
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    
    # Calculate confusion matrix
    tn, fp, fn, tp = confusion_matrix(y_true, y_pred).ravel()
    
    # Total number of samples
    total_samples = len(y_true)
    
    # Convert counts to percentages
    tn_percent = (tn / total_samples) * 100
    fp_percent = (fp / total_samples) * 100
    fn_percent = (fn / total_samples) * 100
    tp_percent = (tp / total_samples) * 100
    
    # Calculate F1 metrics
    metrics = {
        'f1_micro': f1_score(y_true, y_pred, average='micro'),
        'f1_macro': f1_score(y_true, y_pred, average='macro'),
        'f1_weighted': f1_score(y_true, y_pred, average='weighted'),
        'f1_per_class': f1_score(y_true, y_pred, average=None),
        'true_positives_percentage': tp_percent,
        'true_negatives_percentage': tn_percent,
        'false_positives_percentage': fp_percent,
        'false_negatives_percentage': fn_percent
    }
    
    return metrics

results = evaluate_model(model, test_generator)

print(results)

# %%
results = model.evaluate(test_generator)
print(f"Test Results: {results}")

# %%
for name, value in zip(model.metrics_names, results):
    print(f"{name}: {value:.4f}")
# Out:
# loss: 0.4418
# accuracy: 0.8723
# precision: 0.8723
# recall: 0.8723
# f1_metric: 0.9031

# %% [markdown]
# # FOG EPISODE DETECTION

# %%
test_directories = ["data/mean_subtract/gaf_images/AccAP/test", "data/mean_subtract/gaf_images/AccML/test", "data/mean_subtract/gaf_images/AccV/test"]

test_generator = CustomMultiInputDataGenerator(
    directories=test_directories,
    batch_size=32,
    image_size=img_shape,
    augment=False,
    num_classes=2,
    shuffle=False
)

def evaluate_model(model, generator):
    y_true = []
    y_pred = []
    images = []
    for i in range(len(generator)):
        images, batch_y_true = generator[i]
        
        # Get predictions from model
        batch_predictions = model.predict(images, verbose=0)
        
        # Convert softmax output to binary class predictions
        batch_y_pred = np.argmax(batch_predictions, axis=1)
        
        # Flatten ground truth if it's one-hot encoded
        batch_y_true = np.argmax(batch_y_true, axis=1)
        
        y_true.extend(batch_y_true.flatten())
        y_pred.extend(batch_y_pred.flatten())
    
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    
    metrics = {
        'f1_micro': f1_score(y_true, y_pred, average='micro'),
        'f1_macro': f1_score(y_true, y_pred, average='macro'),
        'f1_weighted': f1_score(y_true, y_pred, average='weighted'),
        'f1_per_class': f1_score(y_true, y_pred, average=None)
    }
    
    return metrics, y_true, y_pred

results, y_true, y_pred = evaluate_model(model, test_generator)

print("\nModel Evaluation Results:")
print(results)
# Out:
# total image_paths length: 3, 0: 6255, 1:6255, 2:6255
# batch image paths: [['data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10000_1.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10001_1.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10002_1.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10003_1.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10004_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10005_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10006_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10007_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10008_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10009_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10010_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10011_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10012_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10013_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10014_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10015_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10016_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10017_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10018_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10019_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10020_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10021_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10022_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10023_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10024_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10025_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10026_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10027_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10028_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10029_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10030_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10031_0.jpg'], ['data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10000_1.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10001_1.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10002_1.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10003_1.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10004_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10005_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10006_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10007_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10008_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10009_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10010_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10011_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10012_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10013_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10014_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10015_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10016_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10017_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10018_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10019_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10020_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10021_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10022_0.jpg', 'data/mean_subtra ...
# batch image paths: [['data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10032_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10033_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10034_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10035_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10036_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10037_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10038_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10039_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10040_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10041_1.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10042_1.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10043_1.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10044_1.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10045_1.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10046_1.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10047_1.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10048_1.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10049_1.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10050_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10051_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10052_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10053_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10054_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10055_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10056_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10057_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10058_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10059_1.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10060_1.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10061_1.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10062_1.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10063_1.jpg'], ['data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10032_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10033_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10034_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10035_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10036_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10037_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10038_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10039_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10040_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10041_1.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10042_1.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10043_1.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10044_1.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10045_1.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10046_1.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10047_1.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10048_1.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10049_1.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10050_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10051_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10052_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10053_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10054_0.jpg', 'data/mean_subtra ...
# batch image paths: [['data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10064_1.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10065_1.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10066_1.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10067_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10068_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10069_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10070_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10071_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10072_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10073_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10074_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10075_1.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10076_1.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10077_1.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10078_1.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10079_1.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10080_1.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10081_1.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10082_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10083_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10084_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10085_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10086_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10087_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10088_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10089_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10090_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10091_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10092_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10093_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10094_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10095_0.jpg'], ['data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10064_1.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10065_1.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10066_1.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10067_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10068_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10069_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10070_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10071_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10072_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10073_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10074_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10075_1.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10076_1.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10077_1.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10078_1.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10079_1.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10080_1.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10081_1.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10082_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10083_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10084_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10085_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10086_0.jpg', 'data/mean_subtra ...
# batch image paths: [['data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10096_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10097_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10098_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10099_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10100_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10101_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10102_1.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10103_1.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10104_1.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10105_1.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10106_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10107_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10108_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10109_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10110_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10111_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10112_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10113_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10114_1.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10115_1.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10116_1.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10117_1.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10118_1.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10119_1.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10120_1.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10121_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10122_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10123_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10124_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10125_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10126_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10942_0.jpg'], ['data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10096_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10097_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10098_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10099_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10100_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10101_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10102_1.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10103_1.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10104_1.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10105_1.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10106_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10107_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10108_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10109_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10110_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10111_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10112_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10113_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10114_1.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10115_1.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10116_1.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10117_1.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10118_1.jpg', 'data/mean_subtra ...
# batch image paths: [['data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10943_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10944_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10945_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10946_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10947_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10948_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10949_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10950_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10951_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10952_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10953_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10954_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10955_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10956_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10957_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10958_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10959_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10960_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10961_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10962_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10963_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10964_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10965_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10966_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10967_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10968_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10969_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10970_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10971_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10972_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10973_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10974_0.jpg'], ['data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10943_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10944_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10945_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10946_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10947_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10948_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10949_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10950_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10951_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10952_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10953_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10954_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10955_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10956_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10957_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10958_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10959_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10960_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10961_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10962_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10963_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10964_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10965_0.jpg', 'data/mean_subtra ...
# batch image paths: [['data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10975_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10976_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10977_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10978_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10979_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10980_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10981_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10982_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10983_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10984_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10985_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10986_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10987_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10988_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10989_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10990_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10991_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10992_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10993_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10994_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10995_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10996_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10997_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10998_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_10999_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11000_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11001_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11002_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11003_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11004_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11005_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11006_0.jpg'], ['data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10975_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10976_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10977_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10978_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10979_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10980_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10981_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10982_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10983_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10984_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10985_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10986_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10987_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10988_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10989_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10990_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10991_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10992_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10993_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10994_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10995_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10996_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_10997_0.jpg', 'data/mean_subtra ...
# batch image paths: [['data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11007_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11008_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11009_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11010_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11011_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11012_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11013_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11014_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11015_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11016_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11017_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11018_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11019_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11020_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11021_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11022_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11023_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11024_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11025_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11026_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11027_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11028_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11029_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11030_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11031_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11032_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11033_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11034_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11035_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11036_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11037_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11038_0.jpg'], ['data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11007_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11008_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11009_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11010_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11011_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11012_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11013_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11014_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11015_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11016_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11017_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11018_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11019_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11020_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11021_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11022_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11023_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11024_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11025_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11026_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11027_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11028_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11029_0.jpg', 'data/mean_subtra ...
# batch image paths: [['data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11039_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11040_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11041_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11042_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11043_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11044_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11045_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11046_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11047_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11048_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11049_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11050_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11051_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11052_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11053_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11054_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11055_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11056_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11057_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11058_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11059_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11060_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11061_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11062_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11063_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11064_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11065_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11066_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11067_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11068_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11069_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11070_0.jpg'], ['data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11039_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11040_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11041_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11042_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11043_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11044_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11045_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11046_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11047_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11048_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11049_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11050_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11051_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11052_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11053_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11054_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11055_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11056_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11057_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11058_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11059_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11060_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11061_0.jpg', 'data/mean_subtra ...
# batch image paths: [['data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11071_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11072_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11073_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11074_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11075_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11076_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11077_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11078_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11079_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11080_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11081_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11082_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11083_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11084_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11145_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11146_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11147_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11148_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11149_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11150_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11151_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11152_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11153_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11154_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11155_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11156_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11157_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11158_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11159_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11160_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11161_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11162_0.jpg'], ['data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11071_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11072_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11073_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11074_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11075_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11076_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11077_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11078_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11079_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11080_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11081_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11082_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11083_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11084_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11145_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11146_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11147_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11148_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11149_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11150_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11151_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11152_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11153_0.jpg', 'data/mean_subtra ...
# batch image paths: [['data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11163_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11164_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11165_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11166_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11167_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11168_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11169_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11170_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11171_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11172_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11173_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11174_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11175_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11176_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11177_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11178_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11179_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11180_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11181_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11182_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11183_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11184_1.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11185_1.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11186_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11187_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11188_1.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11189_1.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11190_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11191_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11192_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11193_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11194_0.jpg'], ['data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11163_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11164_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11165_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11166_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11167_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11168_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11169_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11170_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11171_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11172_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11173_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11174_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11175_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11176_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11177_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11178_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11179_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11180_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11181_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11182_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11183_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11184_1.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11185_1.jpg', 'data/mean_subtra ...
# batch image paths: [['data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11195_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11196_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11197_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11198_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11199_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11200_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11201_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11202_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11203_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11204_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11205_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11206_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11207_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11208_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11209_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11210_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11211_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11212_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_11213_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_12054_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_12055_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_12056_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_12057_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_12058_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_12059_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_12060_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_12061_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_12062_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_12063_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_12064_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_12065_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_12066_0.jpg'], ['data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11195_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11196_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11197_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11198_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11199_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11200_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11201_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11202_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11203_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11204_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11205_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11206_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11207_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11208_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11209_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11210_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11211_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11212_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_11213_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_12054_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_12055_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_12056_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_12057_0.jpg', 'data/mean_subtra ...
# ...
# batch image paths: [['data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9677_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9678_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9679_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9680_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9681_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9682_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9683_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9684_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9685_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9686_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9687_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9688_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9689_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9690_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9691_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9692_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9693_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9694_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9695_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9696_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9697_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9698_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9699_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9700_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9701_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9702_1.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9703_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9704_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9705_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9706_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9707_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9708_0.jpg'], ['data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_9677_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_9678_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_9679_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_9680_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_9681_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_9682_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_9683_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_9684_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_9685_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_9686_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_9687_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_9688_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_9689_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_9690_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_9691_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_9692_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_9693_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_9694_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_9695_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_9696_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_9697_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_9698_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_9699_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_9700_0.jpg', ' ...
# batch image paths: [['data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9709_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9710_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9711_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9712_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9713_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9714_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9715_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9716_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9717_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9718_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9719_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9720_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9721_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9722_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9723_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9724_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9725_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9726_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9727_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9728_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9729_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9730_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9731_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9732_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9733_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9734_1.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9735_1.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9736_1.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9737_1.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9738_1.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9739_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9740_0.jpg'], ['data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_9709_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_9710_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_9711_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_9712_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_9713_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_9714_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_9715_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_9716_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_9717_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_9718_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_9719_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_9720_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_9721_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_9722_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_9723_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_9724_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_9725_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_9726_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_9727_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_9728_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_9729_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_9730_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_9731_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_9732_0.jpg', ' ...
# batch image paths: [['data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9741_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9742_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9743_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9744_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9745_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9746_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9747_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9748_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9749_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9750_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9751_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9752_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9753_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9754_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9755_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9756_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9757_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9758_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9759_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9760_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9761_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9974_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9975_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9976_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9977_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9978_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9979_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9980_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9981_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9982_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9983_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9984_0.jpg'], ['data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_9741_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_9742_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_9743_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_9744_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_9745_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_9746_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_9747_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_9748_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_9749_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_9750_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_9751_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_9752_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_9753_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_9754_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_9755_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_9756_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_9757_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_9758_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_9759_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_9760_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_9761_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_9974_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_9975_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_9976_0.jpg', ' ...
# batch image paths: [['data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9985_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9986_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9987_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9988_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9989_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9990_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9991_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9992_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9993_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9994_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9995_0.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9996_1.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9997_1.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9998_1.jpg', 'data/mean_subtract/gaf_images/AccAP/test\\img_AccAP_mean_9999_1.jpg'], ['data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_9985_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_9986_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_9987_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_9988_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_9989_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_9990_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_9991_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_9992_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_9993_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_9994_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_9995_0.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_9996_1.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_9997_1.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_9998_1.jpg', 'data/mean_subtract/gaf_images/AccML/test\\img_AccML_mean_9999_1.jpg'], ['data/mean_subtract/gaf_images/AccV/test\\img_AccV_mean_9985_0.jpg', 'data/mean_subtract/gaf_images/AccV/test\\img_AccV_mean_9986_0.jpg', 'data/mean_subtract/gaf_images/AccV/test\\img_AccV_mean_9987_0.jpg', 'data/mean_subtract/gaf_images/AccV/test\\img_AccV_mean_9988_0.jpg', 'data/mean_subtract/gaf_images/AccV/test\\img_AccV_mean_9989_0.jpg', 'data/mean_subtract/gaf_images/AccV/test\\img_AccV_mean_9990_0.jpg', 'data/mean_subtract/gaf_images/AccV/test\\img_AccV_mean_9991_0.jpg', 'data/mean_subtract/gaf_images/AccV/test\\img_AccV_mean_9992_0.jpg', 'data/mean_subtract/gaf_images/AccV/test\\img_AccV_mean_9993_0.jpg', 'data/mean_subtract/gaf_images/AccV/test\\img_AccV_mean_9994_0.jpg', 'data/mean_subtract/gaf_images/AccV/test\\img_AccV_mean_9995_0.jpg', 'data/mean_subtract/gaf_images/AccV/test\\img_AccV_mean_9996_1.jpg', 'data/mean_subtract/gaf_images/AccV/test\\img_AccV_mean_9997_1.jpg', 'data/mean_subtract/gaf_images/AccV/test\\img_AccV_mean_9998_1.jpg', 'data/mean_subtract/gaf_images/AccV/test\\img_AccV_mean_9999_1.jpg']], labels: 15
#
# Model Evaluation Results:
# {'f1_micro': 0.8767386091127098, 'f1_macro': 0.8595893331443569, 'f1_weighted': 0.8764640324160528, 'f1_per_class': array([0.81051855, 0.90866011])}

# %% [markdown]
# # Verify there weren't any leakage

# %%
train_dir = 'data/mean_subtract/gaf_images/AccML/train'
test_dir = 'data/mean_subtract/gaf_images/AccML/test'
valid_dir = 'data/mean_subtract/gaf_images/AccML/valid'

# Get the list of files in each folder
train_files = set(os.listdir(train_dir))
test_files = set(os.listdir(test_dir))
valid_files = set(os.listdir(valid_dir))

# Find common files
common_files = train_files & test_files & valid_files

# Print or list the common files
print("Common files:", common_files)
# Out:
# Common files: set()

# %%
test_files & valid_files
# Out:
# set()

# %%
# Define the directory path
directories = {
    "train": 'data/mean_subtract/gaf_images/AccAP/train',
    "valid": 'data/mean_subtract/gaf_images/AccAP/valid',
    "test": 'data/mean_subtract/gaf_images/AccAP/test',
}

for type, dir in directories.items():
    count_1 = 0
    count_0 = 0
    print(f"For {type} ==>")
    for filename in os.listdir(dir):
        if filename.endswith('_1.jpg'):
            count_1 += 1
        elif filename.endswith('_0.jpg'):
            count_0 += 1
    
    # Print the counts
    print(f"class 1: {count_1}")
    print(f"class 0: {count_0}")
# Out:
# For train ==>
# class 1: 3182
# class 0: 5106
# For valid ==>
# class 1: 710
# class 0: 1700
# For test ==>
# class 1: 4203
# class 0: 2052
